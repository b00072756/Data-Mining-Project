# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, Binarizer, OneHotEncoder, OrdinalEncoder
from scipy.stats import pearsonr, spearmanr, chi2_contingency, pointbiserialr, f_oneway

from sklearn.impute import SimpleImputer

pd.set_option("display.max_columns", None) # to display all columns in a dataframe

# %%
df = pd.read_csv('Final_Upwork_Dataset.csv')

# %%
df.describe()
# Out:
#        Freelancers_Num      Spent($)  Connects_Num  New_Connects_Num  \
# count     63950.000000  6.230400e+04  63949.000000      63949.000000
# mean          1.137654  2.999789e+04      4.506701          9.013401
# std           2.391479  3.926514e+05      2.097518          4.195035
# min           0.000000  0.000000e+00      1.000000          2.000000
# 25%           1.000000  0.000000e+00      2.000000          4.000000
# 50%           1.000000  8.000000e+01      4.000000          8.000000
# 75%           1.000000  4.000000e+03      6.000000         12.000000
# max          99.000000  7.000000e+07      8.000000         16.000000
#
#              Rating  Feedback_Num
# count  30593.000000  63949.000000
# mean       4.823875     20.997029
# std        0.418398    180.450288
# min        1.000000      0.000000
# 25%        4.842153      0.000000
# 50%        4.975717      0.000000
# 75%        5.000000     10.000000
# max        5.000000  12541.000000

# %%
drop_urls = ['Category1_URL_search','Category2_URL_search','Category3_URL_search','Category4_URL_search','Category5_URL_search','Category6_URL_search' ,'Category7_URL_search','Category8_URL_search','Category9_URL_search']

missing = df.isnull().sum()
print(missing)
# Out:
# Job Title                   2
# Job_URL                     1
# EX_level_demand          7015
# Time_Limitation         40916
# Search_Keyword              1
# Posted_from                37
# Description                 2
# Category1_URL_search      445
# Category_1                445
# highlight               13819
# Category2_URL_search     4061
# Category_2               4061
# Category3_URL_search     8953
# Category_3               8953
# Category4_URL_search    16407
# Category_4              16407
# Category5_URL_search    24372
# Category_5              24372
# Category6_URL_search    32643
# Category_6              32643
# Category7_URL_search    38758
# Category_7              38758
# Category8_URL_search    43514
# Category_8              43514
# Category9_URL_search    47469
# Category_9              47469
# Applicants_Num              1
# Payment_Situation           1
# Enterprise_Client       63897
# Freelancers_Num             0
# Spent($)                 1646
# Client_Country            125
# Connects_Num                1
# New_Connects_Num            1
# Rating                  33357
# Feedback_Num                1
# Payment_type                1
# Job_Cost                43837
# Hourly_Rate             37380
# Start_rate                  1
# End_rate                37987
# dtype: int64

# %%
df_cleaned = df.drop(['Category1_URL_search','Category2_URL_search','Category3_URL_search','Category4_URL_search','Category5_URL_search','Category6_URL_search' ,'Category7_URL_search','Category8_URL_search','Category9_URL_search'], axis=1)

# %%
df_cleaned_new = df_cleaned.drop(['Connects_Num','Posted_from','highlight','Job_URL','Category_4','Category_5','Category_6','Category_7','Category_8','Category_9','Enterprise_Client','Rating','Time_Limitation'], axis=1)

# %%
df_cleaned_new.head(20)
# Out:
#                                             Job Title EX_level_demand  \
# 0                       Power bi specialist freelance          Expert
# 1             Case Study (on-demand delivery startup)    Intermediate
# 2   File Maker Pro Reports, Charts, Query and Ongo...    Intermediate
# 3           Implementation of EleutherAI/gpt-neox-20b          Expert
# 4   BI and Data Engineer for Upwork Finance System...          Expert
# 5   Computer vision / machine learning: synthetic ...          Expert
# 6                            Expert in Data Analytics          Expert
# 7      Data Analytics Expert for Educational Exercise    Intermediate
# 8                       Azure Data Factory specialist    Intermediate
# 9   Implementation of algorithm for multilingual data          Expert
# 10      Descarga e Interrelación entre Bases de Datos    Intermediate
# 11                      Linear regression with Matlab    Intermediate
# 12  Culture Survey data analysis and theme extraction    Intermediate
# 13  Integrate Bank Balance and Transaction Data in...    Intermediate
# 14      Create a face model file for stable diffusion    Intermediate
# 15    Scrape Data from our Google Maps into CSV Excel    Intermediate
# 16                          AI enabled Chat Interface    Intermediate
# 17  Programmer and expert training AI models (tens...          Expert
# 18                            Data mining / scraping.    Intermediate
# 19                                       Excel expert     Entry level
#
#    Search_Keyword                                        Description  \
# 0    Data_science  Already data pooled and designed. Need to refi...
# 1    Data_science  Hi,\n\nWould you be able to help me do a case-...
# 2    Data_science  NITIAL PROJECT\n\nSet up Monthly Report mimick...
# 3    Data_science  As a first step, you will implement the instal...
# 4    Data_science  The Upwork Finance Systems team is looking for...
# 5    Data_science  Our company is working on a government proposa...
# 6    Data_science  Mission : Ensure smooth transition of Analytic...
# 7    Data_science  Looking for someone to help me solve some prob...
# 8    Data_science  1. Good work experience in Azure Data Factory ...
# 9    Data_science  Looking for freelancer to implement following ...
# 10   Data_science  Se desea desarrollar un entorno de interconexi...
# 11   Data_science  Linear regression with a possible GUI. I alrea...
# 12   Data_science  I have 3 sets of data with ~60 responses each ...
# 13   Data_science  I'm looking for someone to build a solution to...
# 14   Data_science  For this job i will provide you with photo and...
# 15   Data_science  We have a list of businesses with contact name...
# 16   Data_science  Looking to develop a Chat-GPT style UI, which ...
# 17   Data_science  Programmer and expert training AI models (tens...
# 18   Data_science  We are a new cleaning service business in FL\n...
# 19   Data_science  Need someone who can clean my raw data in exce...
#
#                         Category_1               Category_2  \
# 0                    Data Analysis       Data Visualization
# 1               Google Data Studio                      SQL
# 2                   Report Writing          Custom Graphics
# 3           Machine Learning Model         Machine Learning
# 4                    Data Analysis                   Looker
# 5   Generative Adversarial Network         Machine Learning
# 6               Data Visualization            Data Analysis
# 7                   Data Analytics                 Big Data
# 8                              SQL          Microsoft Azure
# 9                     Data Science    Algorithm Development
# 10                 Data Extraction                      ETL
# 11                   Data Analysis                   MATLAB
# 12                   Data Analysis             SurveyMonkey
# 13                        BigQuery                      API
# 14          Deep Learning Modeling       Model Optimization
# 15                   Data Scraping          Data Extraction
# 16                         Chatbot  Artificial Intelligence
# 17          Machine Learning Model         Machine Learning
# 18                      Data Entry            Data Scraping
# 19                   Data Analysis       Data Visualization
#
#                Category_3 Applicants_Num   Payment_Situation  Freelancers_Num  \
# 0      Microsoft Power BI    Less than 5  Payment unverified                1
# 1                 Tableau    Less than 5    Payment verified                1
# 2                     NaN    Less than 5    Payment verified                1
# 3                  Python    Less than 5    Payment verified                1
# 4                     SQL    Less than 5    Payment verified                1
# 5         Computer Vision    Less than 5    Payment verified                1
# 6      Microsoft Power BI    Less than 5    Payment verified                1
# 7      Data Visualization    Less than 5    Payment verified                1
# 8                     ETL    Less than 5    Payment verified                1
# 9                  Python    Less than 5    Payment verified                1
# 10                    NaN    Less than 5  Payment unverified                1
# 11             Statistics        5 to 10  Payment unverified                1
# 12             Statistics    Less than 5    Payment verified                1
# 13  Google Cloud Platform    Less than 5    Payment verified                1
# 14           Model Tuning    Less than 5    Payment verified                1
# 15                    NaN            50+    Payment verified                1
# 16                 Python       20 to 50    Payment verified                1
# 17                 Python    Less than 5    Payment verified                1
# 18        Data Extraction       10 to 15    Payment verified                1
# 19        Microsoft Excel        5 to 10  Payment unverified                1
#
#       Spent($) Client_Country  New_Connects_Num  Feedback_Num Payment_type  \
# 0          0.0  United States              12.0           0.0  Fixed-price
# 1        100.0         Canada               8.0           1.0  Fixed-price
# 2        200.0  United States              12.0           1.0       Hourly
# 3     200000.0         Canada              12.0          26.0       Hourly
# 4          NaN  United States              12.0       12512.0       Hourly
# 5     100000.0  United States              12.0          11.0       Hourly
# 6   70000000.0  United States              12.0       10906.0       Hourly
# 7        600.0      Australia               4.0           6.0  Fixed-price
# 8          0.0         Poland              12.0           0.0       Hourly
# 9      20000.0       Pakistan               4.0          68.0       Hourly
# 10         0.0        Bolivia               4.0           0.0       Hourly
# 11         0.0        Germany               4.0           0.0  Fixed-price
# 12     10000.0  United States               4.0         185.0       Hourly
# 13     10000.0  United States               4.0           5.0       Hourly
# 14     20000.0         Canada               4.0          37.0  Fixed-price
# 15       200.0         Canada               4.0           1.0       Hourly
# 16      2000.0      Australia               8.0           3.0  Fixed-price
# 17       100.0         Israel               8.0           1.0  Fixed-price
# 18      3000.0  United States               4.0           4.0  Fixed-price
# 19         0.0          India               8.0           0.0       Hourly
#
#    Job_Cost     Hourly_Rate Start_rate  End_rate
# 0   $2,500              NaN          0       NaN
# 1     $200              NaN          0       NaN
# 2       NaN         $40.00          40       NaN
# 3       NaN  $35.00-$100.00    $35.00   $100.00
# 4       NaN             NaN          0       NaN
# 5       NaN  $75.00-$175.00    $75.00   $175.00
# 6       NaN             NaN          0       NaN
# 7      $10              NaN          0       NaN
# 8       NaN   $25.00-$35.00    $25.00    $35.00
# 9       NaN             NaN          0       NaN
# 10      NaN    $8.00-$25.00     $8.00    $25.00
# 11     $80              NaN          0       NaN
# 12      NaN   $45.00-$73.00    $45.00    $73.00
# 13      NaN   $10.00-$60.00    $10.00    $60.00
# 14     $20              NaN          0       NaN
# 15      NaN    $8.00-$25.00     $8.00    $25.00
# 16    $500              NaN          0       NaN
# 17    $500              NaN          0       NaN
# 18     $20              NaN          0       NaN
# 19      NaN   $10.00-$35.00    $10.00    $35.00

# %%
print(df_cleaned_new.isnull().sum())
# Out:
# Job Title                2
# EX_level_demand       7015
# Search_Keyword           1
# Description              2
# Category_1             445
# Category_2            4061
# Category_3            8953
# Applicants_Num           1
# Payment_Situation        1
# Freelancers_Num          0
# Spent($)              1646
# Client_Country         125
# New_Connects_Num         1
# Feedback_Num             1
# Payment_type             1
# Job_Cost             43837
# Hourly_Rate          37380
# Start_rate               1
# End_rate             37987
# dtype: int64

# %%
miss_hour = df_cleaned_new['Hourly_Rate'].isnull() 
miss_fixed = df_cleaned_new['Job_Cost'].isnull() 

miss_fixed.sum()
# Out:
# np.int64(43837)
